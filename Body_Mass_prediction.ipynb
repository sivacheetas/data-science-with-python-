# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#500_Person_Gender_Height_Weight_Index (2).csv

# %%
data1 = pd.read_csv('data/500_Person_Gender_Height_Weight_Index (2).csv')
data1
# Out:
#      Gender  Height  Weight  Body_Mass
# 0      Male     174      96          4
# 1      Male     189      87          2
# 2    Female     185     110          4
# 3    Female     195     104          3
# 4      Male     149      61          3
# ..      ...     ...     ...        ...
# 495  Female     150     153          5
# 496  Female     184     121          4
# 497  Female     141     136          5
# 498    Male     150      95          5
# 499    Male     173     131          5
#
# [500 rows x 4 columns]

# %%
data1.head()
# Out:
#    Gender  Height  Weight  Body_Mass
# 0    Male     174      96          4
# 1    Male     189      87          2
# 2  Female     185     110          4
# 3  Female     195     104          3
# 4    Male     149      61          3

# %%
data1.tail()
# Out:
#      Gender  Height  Weight  Body_Mass
# 495  Female     150     153          5
# 496  Female     184     121          4
# 497  Female     141     136          5
# 498    Male     150      95          5
# 499    Male     173     131          5

# %%
data1.columns
# Out:
# Index(['Gender', 'Height', 'Weight', 'Body_Mass'], dtype='object')

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
# Gender       500 non-null object
# Height       500 non-null int64
# Weight       500 non-null int64
# Body_Mass    500 non-null int64
# dtypes: int64(3), object(1)
# memory usage: 13.7+ KB

# %%
data1.shape
# Out:
# (500, 4)

# %%
type(data1)
# Out:
# pandas.core.frame.DataFrame

# %%
data1.describe()
# Out:
#            Height      Weight   Body_Mass
# count  500.000000  500.000000  500.000000
# mean   169.944000  106.000000    3.748000
# std     16.375261   32.382607    1.355053
# min    140.000000   50.000000    0.000000
# 25%    156.000000   80.000000    3.000000
# 50%    170.500000  106.000000    4.000000
# 75%    184.000000  136.000000    5.000000
# max    199.000000  160.000000    5.000000

# %%
data1.index
# Out:
# RangeIndex(start=0, stop=500, step=1)

# %%
data1.values
# Out:
# array([['Male', 174, 96, 4],
#        ['Male', 189, 87, 2],
#        ['Female', 185, 110, 4],
#        ...,
#        ['Female', 141, 136, 5],
#        ['Male', 150, 95, 5],
#        ['Male', 173, 131, 5]], dtype=object)

# %%
data1['Height']
# Out:
# 0      174
# 1      189
# 2      185
# 3      195
# 4      149
#       ...
# 495    150
# 496    184
# 497    141
# 498    150
# 499    173
# Name: Height, Length: 500, dtype: int64

# %%
from sklearn import linear_model
Height = data1['Height']
Weight = data1['Weight']
Index = data1['Body_Mass']

# %%
Index
# Out:
# 0      4
# 1      2
# 2      4
# 3      3
# 4      3
#       ..
# 495    5
# 496    4
# 497    5
# 498    5
# 499    5
# Name: Body_Mass, Length: 500, dtype: int64

# %%
data1.dropna(axis='columns',how='any')
# Out:
#      Gender  Height  Weight  Body_Mass
# 0      Male     174      96          4
# 1      Male     189      87          2
# 2    Female     185     110          4
# 3    Female     195     104          3
# 4      Male     149      61          3
# ..      ...     ...     ...        ...
# 495  Female     150     153          5
# 496  Female     184     121          4
# 497  Female     141     136          5
# 498    Male     150      95          5
# 499    Male     173     131          5
#
# [500 rows x 4 columns]

# %%
data1['Gender']=data1['Gender'].replace('Male',0)
data1['Gender']=data1['Gender'].replace('Female',1)

# %%
x = data1[['Height','Weight']]
x.head(2)
# Out:
#    Height  Weight
# 0     174      96
# 1     189      87

# %%
y = data1[['Body_Mass']]
y.head(3)
# Out:
#    Body_Mass
# 0          4
# 1          2
# 2          4

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2)

# %%
data1.shape
# Out:
# (500, 4)

# %%
x_train.shape
# Out:
# (400, 2)

# %%
x_test.shape
# Out:
# (100, 2)

# %%
y_train.shape
# Out:
# (400, 1)

# %%
y_test.shape
# Out:
# (100, 1)

# %%
from sklearn import linear_model
sk_model = linear_model.LinearRegression()

# %%
sk_model.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
sk_model.coef_
# Out:
# array([[-0.03353797,  0.03217434]])

# %%
sk_model.intercept_
# Out:
# array([6.04602266])

# %%
sk_model.rank_
# Out:
# 2

# %%
new_predict = sk_model.predict(x_test)

# %%
sk_model.score(x_test,y_test)
# Out:
# 0.8354209146931079

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
mean_absolute_error(y_test,new_predict)
# Out:
# 0.5239036558390915

# %%
mean_squared_error(y_test,new_predict)
# Out:
# 0.402412321483882

# %%
r2_score(y_test,new_predict)
# Out:
# 0.8354209146931079

# %%
from sklearn.model_selection import cross_val_predict

# %%
cv_result = cross_val_predict(sk_model,x_train,y_train,cv = 30)
cv_result
# Out:
# array([[4.93269449],
#        [4.97661078],
#        [3.66917469],
#        [2.45441246],
#        [4.2541997 ],
#        [4.40901439],
#        [1.94331971],
#        [4.90945632],
#        [1.91119486],
#        [3.3440532 ],
#        [2.03291644],
#        [2.89721014],
#        [2.74837736],
#        [5.21116727],
#        [3.48948727],
#        [3.55431512],
#        [2.06041954],
#        [2.85565238],
#        [5.75543893],
#        [3.38116096],
#        [4.00323964],
#        [5.50838776],
#        [4.12785691],
#        [4.10854289],
#        [2.34912181],
#        [3.72864497],
#        [3.35496115],
#        [2.95692489],
#        [3.50870428],
#        [4.57308979],
#        [3.8027896 ],
#        [2.84331361],
#        [4.33505656],
#        [2.16964975],
#        [2.83805873],
#        [2.6976317 ],
#        [2.93566494],
#        [5.90450447],
#        [3.37017728],
#        [4.40337004],
#        [3.45790707],
#        [5.29229598],
#        [3.43641512],
# ...

# %%
np.mean(cv_result)
# Out:
# 3.7926744909324785

# %%
np.max(cv_result)
# Out:
# 6.411357195242234

# %%
np.min(cv_result)
# Out:
# 1.0432776228560545

# %%
x_test
# Out:
#      Height  Weight
# 466     188      99
# 253     162     159
# 369     147      67
# 418     162     130
# 42      157      56
# ..      ...     ...
# 97      160     139
# 231     153      78
# 476     164     142
# 433     179     127
# 457     175      83
#
# [100 rows x 2 columns]

# %%
sk_model.predict([[159,104]])
# Out:
# array([[4.05961709]])

# %%
sk_model.predict([[174,96]])
# Out:
# array([[3.29915288]])
